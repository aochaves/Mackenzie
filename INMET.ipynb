# %% [markdown]
# <b>Banco de Dados Meteorológicos do INMET</b> - https://bdmep.inmet.gov.br/
#
# Este notebookcarrega os dados climáticos obtidos do INMET.

# %% [markdown]
# ## Amostra dos dados brutos (INMET)
#
# Os arquivos do INMET normalmente incluem **metadados nas primeiras linhas** (ex.: `REGIAO:`, `UF:`, `ESTACAO:`) e o cabeçalho real dos dados aparece a partir da 9ª linha.

# %%
arquivo = open("/Volumes/aula/python/root/dados/INMET_S_SC_A841_JOACABA_01-01-2025_A_31-10-2025.CSV", "r", encoding="latin1").read()
print(arquivo[:1100]) # Imprime os primeiros 500 caracteres
# Out:
# REGIAO:;S
# UF:;SC
# ESTACAO:;JOACABA
# CODIGO (WMO):;A841
# LATITUDE:;-27,16916666
# LONGITUDE:;-51,55888888
# ALTITUDE:;767,63
# DATA DE FUNDACAO:;20/09/07
# Data;Hora UTC;PRECIPITAÇÃO TOTAL, HORÁRIO (mm);PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB);PRESSÃO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB);PRESSÃO ATMOSFERICA MIN. NA HORA ANT. (AUT) (mB);RADIACAO GLOBAL (Kj/m²);TEMPERATURA DO AR - BULBO SECO, HORARIA (°C);TEMPERATURA DO PONTO DE ORVALHO (°C);TEMPERATURA MÁXIMA NA HORA ANT. (AUT) (°C);TEMPERATURA MÍNIMA NA HORA ANT. (AUT) (°C);TEMPERATURA ORVALHO MAX. NA HORA ANT. (AUT) (°C);TEMPERATURA ORVALHO MIN. NA HORA ANT. (AUT) (°C);UMIDADE REL. MAX. NA HORA ANT. (AUT) (%);UMIDADE REL. MIN. NA HORA ANT. (AUT) (%);UMIDADE RELATIVA DO AR, HORARIA (%);VENTO, DIREÇÃO HORARIA (gr) (° (gr));VENTO, RAJADA MAXIMA (m/s);VENTO, VELOCIDADE HORARIA (m/s);
# 2025/01/01;0000 UTC;;;;;;;;;;;;;;;;;;
# 2025/01/01;0100 UTC;;;;;;;;;;;;;;;;;;
# 2025/01/01;0200 UTC;;;;;;;;;;;;;;;;;;
# 2025/01/01;0300 UTC;;;;;;;;;;;;;;;;;;
# 2025/01/01;0400 UTC;;;;;;;;;;;;;;;;;;
# 2025/01/01;0500 UTC;;;;;;;;;;;;;;;;;;
# 2025/01/01;0600 UTC;;;;;;

# %% [markdown]
# ## 1. **Coleta/Aquisição:**
#
#  Simular a ingestão de dados de uma fonte de logs ou transações em tempo real (pode ser um dataset CSV/JSON grande) na camada Raw (Bruta).

# %%
from pyspark.sql.types import *

# definicao do schema na camada RAW
schema_inmet = {
    "Data": ("DATA", "string"),
    "Hora UTC": ("HORA_UTC", "string"),
    "PRECIPITAÇÃO TOTAL, HORÁRIO (mm)": ("PRECIPITACAO_TOTAL_MM", "string"),
    "PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)": ("PRESSAO_ATMOSFERICA_ESTACAO_MB", "string"),
    "PRESSÃO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)": ("PRESSAO_ATMOSFERICA_MAX_HORA_ANT_MB", "string"),
    "PRESSÃO ATMOSFERICA MIN. NA HORA ANT. (AUT) (mB)": ("PRESSAO_ATMOSFERICA_MIN_HORA_ANT_MB", "string"),
    "RADIACAO GLOBAL (Kj/m²)": ("RADIACAO_GLOBAL_KJ_M2", "string"),
    "TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)": ("TEMPERATURA_AR_C", "string"),
    "TEMPERATURA DO PONTO DE ORVALHO (°C)": ("TEMPERATURA_PONTO_ORVALHO_C", "string"),
    "TEMPERATURA MÁXIMA NA HORA ANT. (AUT) (°C)": ("TEMPERATURA_MAX_HORA_ANT_C", "string"),
    "TEMPERATURA MÍNIMA NA HORA ANT. (AUT) (°C)": ("TEMPERATURA_MIN_HORA_ANT_C", "string"),
    "TEMPERATURA ORVALHO MAX. NA HORA ANT. (AUT) (°C)": ("TEMPERATURA_ORVALHO_MAX_HORA_ANT_C", "string"),
    "TEMPERATURA ORVALHO MIN. NA HORA ANT. (AUT) (°C)": ("TEMPERATURA_ORVALHO_MIN_HORA_ANT_C", "string"),
    "UMIDADE REL. MAX. NA HORA ANT. (AUT) (%)": ("UMIDADE_REL_MAX_HORA_ANT_PCT", "string"),
    "UMIDADE REL. MIN. NA HORA ANT. (AUT) (%)": ("UMIDADE_REL_MIN_HORA_ANT_PCT", "string"),
    "UMIDADE RELATIVA DO AR, HORARIA (%)": ("UMIDADE_RELATIVA_PCT", "string"),
    "VENTO, DIREÇÃO HORARIA (gr) (° (gr))": ("VENTO_DIRECAO_GRAUS", "string"),
    "VENTO, RAJADA MAXIMA (m/s)": ("VENTO_RAJADA_MAX_MS", "string"),
    "VENTO, VELOCIDADE HORARIA (m/s)": ("VENTO_VELOCIDADE_MS", "string"),
    "Unnamed: 19": ("COLUNA_EXTRA", "string"),
    "METADADOS": ("METADADOS", "string")
}

# %%
import glob
arquivos = glob.glob("/Volumes/aula/python/root/dados/*.CSV")  # Lista os arquivos de uma pasta
qtd = len(arquivos)
print(arquivos[:5])
print(qtd)
# Out:
# ['/Volumes/aula/python/root/dados/INMET_CO_DF_A001_BRASILIA_01-01-2025_A_31-10-2025.CSV', '/Volumes/aula/python/root/dados/INMET_CO_DF_A042_BRAZLANDIA_01-01-2025_A_31-10-2025.CSV', '/Volumes/aula/python/root/dados/INMET_CO_DF_A045_AGUAS EMENDADAS_01-01-2025_A_31-10-2025.CSV', '/Volumes/aula/python/root/dados/INMET_CO_DF_A046_GAMA (PONTE ALTA)_01-01-2025_A_31-10-2025.CSV', '/Volumes/aula/python/root/dados/INMET_CO_DF_A047_PARANOA (COOPA-DF)_01-01-2025_A_31-10-2025.CSV']
# 570

# %%
import json
import pandas as pd
import pyspark.sql.functions as F

# DataFrame vazio para acumular os arquivos
df_raw_inmet = None
n = 0
METADADOS = {}

# Loop sobre cada arquivo
for arq in arquivos[:35]:
    print(f" - Processando arquivo {n} de {qtd}: {arq}")

    # acessa o cabeçalho do arquivo e cria um json com os metadados
    with open(arquivos[n], "r", encoding="latin1") as f:
        for i in range(8):
            chave, valor = f.readline().strip().split(";", 1)
            METADADOS[chave.replace(":", "")] = valor
    
    metadata_json = json.dumps(METADADOS, ensure_ascii=False)
    
    df_pd = pd.read_csv(arquivos[n],
                    sep=";",
                    encoding="latin1",
                    header=0,
                    skiprows=8
                )  
    n += 1

    # Convert pandas DataFrame to Spark DataFrame
    df = spark.createDataFrame(df_pd)

    # Adicionar coluna de metadados
    df = df.withColumn("METADADOS", F.lit(metadata_json))

    # Aplica schema correto para o dataframe
    for old_name, (new_name, new_type) in schema_inmet.items():
        df = df.withColumnRenamed(old_name, new_name).withColumn(new_name, F.col(new_name).cast(new_type))
    
    # append
    if df_raw_inmet is None:
        df_raw_inmet = df
    else:
        df_raw_inmet = df_raw_inmet.unionByName(df, allowMissingColumns=True)

print(" ----- - Quantidade de linhas carregadas:", df_raw_inmet.count())
# Out:
#  - Processando arquivo 0 de 570: /Volumes/aula/python/root/dados/INMET_CO_DF_A001_BRASILIA_01-01-2025_A_31-10-2025.CSV
#  - Processando arquivo 1 de 570: /Volumes/aula/python/root/dados/INMET_CO_DF_A042_BRAZLANDIA_01-01-2025_A_31-10-2025.CSV
#  - Processando arquivo 2 de 570: /Volumes/aula/python/root/dados/INMET_CO_DF_A045_AGUAS EMENDADAS_01-01-2025_A_31-10-2025.CSV
#  - Processando arquivo 3 de 570: /Volumes/aula/python/root/dados/INMET_CO_DF_A046_GAMA (PONTE ALTA)_01-01-2025_A_31-10-2025.CSV
#  - Processando arquivo 4 de 570: /Volumes/aula/python/root/dados/INMET_CO_DF_A047_PARANOA (COOPA-DF)_01-01-2025_A_31-10-2025.CSV
#  - Processando arquivo 5 de 570: /Volumes/aula/python/root/dados/INMET_CO_GO_A002_GOIANIA_01-01-2025_A_31-10-2025.CSV
#  - Processando arquivo 6 de 570: /Volumes/aula/python/root/dados/INMET_CO_GO_A003_MORRINHOS_01-01-2025_A_31-10-2025.CSV
#  - Processando arquivo 7 de 570: /Volumes/aula/python/root/dados/INMET_CO_GO_A005_PORANGATU_01-01-2025_A_31-10-2025.CSV
#  - Processando arquivo 8 de 570: /Volumes/aula/python/root/dados/INMET_CO_GO_A011_SAO SIMAO_01-01-2025_A_31-10-2025.CSV
#  - Processando arquivo 9 de 570: /Volumes/aula/python/root/dados/INMET_CO_GO_A012_LUZIANIA_01-01-2025_A_31-10-2025.CSV
#  - Processando arquivo 10 de 570: /Volumes/aula/python/root/dados/INMET_CO_GO_A013_ARAGARCAS_01-01-2025_A_31-10-2025.CSV
#  - Processando arquivo 11 de 570: /Volumes/aula/python/root/dados/INMET_CO_GO_A014_GOIAS_01-01-2025_A_31-10-2025.CSV
#  - Processando arquivo 12 de 570: /Volumes/aula/python/root/dados/INMET_CO_GO_A015_ITAPACI_01-01-2025_A_31-10-2025.CSV
#  - Processando arquivo 13 de 570: /Volumes/aula/python/root/dados/INMET_CO_GO_A016_JATAI_01-01-2025_A_31-10-2025.CSV
#  - Processando arquivo 14 de 570: /Volumes/aula/python/root/dados/INMET_CO_GO_A017_POSSE_01-01-2025_A_31-10-2025.CSV
#  - Processando arquivo 15 de 570: /Volumes/aula/python/root/dados/INMET_CO_GO_A022_GOIANESIA_01-01-2025_A_31-10-2025.CSV
#  - Processando arquivo 16 de 570: /Volumes/aula/python/root/dados/INMET_CO_GO_A023_CAIAPONIA_01-01-2025_A_31-10-2025.CSV
#  - Processando arquivo 17 de 570: /Volumes/aula/python/root/dados/INMET_CO_GO_A024_ALTO PARAISO DE GOIAS_01-01-2025_A_31-10-2025.CSV
#  - Processando arquivo 18 de 570: /Volumes/aula/python/root/dados/INMET_CO_GO_A025_RIO VERDE_01-01-2025_A_31-10-2025.CSV
#  - Processando arquivo 19 de 570: /Volumes/aula/python/root/dados/INMET_CO_GO_A026_MINEIROS_01-01-2025_A_31-10-2025.CSV
#  - Processando arquivo 20 de 570: /Volumes/aula/python/root/dados/INMET_CO_GO_A027_PARAUNA_01-01-2025_A_31-10-2025.CSV
#  - Processando arquivo 21 de 570: /Volumes/aula/python/root/dados/INMET_CO_GO_A028_IPORA_01-01-2025_A_31-10-2025.CSV
#  - Processando arquivo 22 de 570: /Volumes/aula/python/root/dados/INMET_CO_GO_A029_EDEIA_01-01-2025_A_31-10-2025.CSV
#  - Processando arquivo 23 de 570: /Volumes/aula/python/root/dados/INMET_CO_GO_A031_SAO MIGUEL DO ARAGUAIA_01-01-2025_A_31-10-2025.CSV
#  - Processando arquivo 24 de 570: /Volumes/aula/python/root/dados/INMET_CO_GO_A032_MONTE ALEGRE DE GOIAS_01-01-2025_A_31-10-2025.CSV
#  - Processando arquivo 25 de 570: /Volumes/aula/python/root/dados/INMET_CO_GO_A033_PIRES DO RIO_01-01-2025_A_31-10-2025.CSV
#  - Processando arquivo 26 de 570: /Volumes/aula/python/root/dados/INMET_CO_GO_A034_CATALAO_01-01-2025_A_31-10-2025.CSV
#  - Processando arquivo 27 de 570: /Volumes/aula/python/root/dados/INMET_CO_GO_A035_ITUMBIARA_01-01-2025_A_31-10-2025.CSV
#  - Processando arquivo 28 de 570: /Volumes/aula/python/root/dados/INMET_CO_GO_A036_CRISTALINA_01-01-2025_A_31-10-2025.CSV
#  - Processando arquivo 29 de 570: /Volumes/aula/python/root/dados/INMET_CO_GO_A037_SILVANIA_01-01-2025_A_31-10-2025.CSV
#  - Processando arquivo 30 de 570: /Volumes/aula/python/root/dados/INMET_CO_GO_A056_CRISTALINA (FAZENDA SANTA MONICA)_01-01-2025_A_31-10-2025.CSV
#  - Processando arquivo 31 de 570: /Volumes/aula/python/root/dados/INMET_CO_MS_A702_CAMPO GRANDE_01-01-2025_A_31-10-2025.CSV
#  - Processando arquivo 32 de 570: /Volumes/aula/python/root/dados/INMET_CO_MS_A703_PONTA PORA_01-01-2025_A_31-10-2025.CSV
#  - Processando arquivo 33 de 570: /Volumes/aula/python/root/dados/INMET_CO_MS_A704_TRES LAGOAS_01-01-2025_A_31-10-2025.CSV
#  - Processando arquivo 34 de 570: /Volumes/aula/python/root/dados/INMET_CO_MS_A709_IVINHEMA_01-01-2025_A_31-10-2025.CSV
#  ----- - Quantidade de linhas carregadas: 255360

# %%
# Definindo o caminho de saída (simulação de um Data Lake)
caminho_parquet = "/Volumes/aula/python/root/raw/RAW_INMET"

# Ação: Salvar o DataFrame tratado em Parquet
(
    df_raw_inmet.write
    .mode("overwrite") # Sobrescreve se o diretório já existir
    .option("compression", "snappy") # Snappy é o padrão (bom trade-off)
    .parquet(caminho_parquet)
)

# %%
dados = spark.read.parquet("/Volumes/aula/python/root/raw/RAW_INMET")
display(dados.limit(2))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>DATA</th><th>HORA_UTC</th><th>PRECIPITACAO_TOTAL_MM</th><th>PRESSAO_ATMOSFERICA_ESTACAO_MB</th><th>PRESSAO_ATMOSFERICA_MAX_HORA_ANT_MB</th><th>PRESSAO_ATMOSFERICA_MIN_HORA_ANT_MB</th><th>RADIACAO_GLOBAL_KJ_M2</th><th>TEMPERATURA_AR_C</th><th>TEMPERATURA_PONTO_ORVALHO_C</th><th>TEMPERATURA_MAX_HORA_ANT_C</th><th>TEMPERATURA_MIN_HORA_ANT_C</th><th>TEMPERATURA_ORVALHO_MAX_HORA_ANT_C</th><th>TEMPERATURA_ORVALHO_MIN_HORA_ANT_C</th><th>UMIDADE_REL_MAX_HORA_ANT_PCT</th><th>UMIDADE_REL_MIN_HORA_ANT_PCT</th><th>UMIDADE_RELATIVA_PCT</th><th>VENTO_DIRECAO_GRAUS</th><th>VENTO_RAJADA_MAX_MS</th><th>VENTO_VELOCIDADE_MS</th><th>COLUNA_EXTRA</th><th>METADADOS</th></tr></thead><tbody><tr><td>2025/07/10</td><td>0000 UTC</td><td>0</td><td>914,8</td><td>914,8</td><td>914,3</td><td>null</td><td>16,7</td><td>9,2</td><td>17,8</td><td>16,4</td><td>9,3</td><td>8,8</td><td>63.0</td><td>56.0</td><td>61.0</td><td>129.0</td><td>5,5</td><td>1,8</td><td>null</td><td>{"REGIAO": "CO", "UF": "GO", "ESTACAO": "CRISTALINA (FAZENDA SANTA MONICA)", "CODIGO (WMO)": "A056", "LATITUDE": "-16,39944444", "LONGITUDE": "-47,62583332", "ALTITUDE": "932", "DATA DE FUNDACAO": "25/01/18"}</td></tr><tr><td>2025/07/10</td><td>0100 UTC</td><td>0</td><td>915,1</td><td>915,1</td><td>914,8</td><td>null</td><td>15,9</td><td>8,7</td><td>16,7</td><td>15,4</td><td>9,3</td><td>8,6</td><td>65.0</td><td>61.0</td><td>62.0</td><td>117.0</td><td>5,5</td><td>1,2</td><td>null</td><td>{"REGIAO": "CO", "UF": "GO", "ESTACAO": "CRISTALINA (FAZENDA SANTA MONICA)", "CODIGO (WMO)": "A056", "LATITUDE": "-16,39944444", "LONGITUDE": "-47,62583332", "ALTITUDE": "932", "DATA DE FUNDACAO": "25/01/18"}</td></tr></tbody></table></div>

# %% [markdown]
# ## 2. Pré-processamento:
#
# Aplicar pelo menos 3 transformações de qualidade (ex: limpeza de nulos, casting de tipos, desduplicação). Mover para a camada Curated (Tratada).

# %%
dados = spark.read.parquet("/Volumes/aula/python/root/raw/RAW_INMET")

df_silver = dados.withColumn("DataHora",
                    F.to_timestamp(
                                F.concat_ws(" ", 
                                            F.to_date(F.col("Data"), "yyyy/MM/dd"), # formatando o campo de data
                                            F.date_format(F.concat(F.substring("HORA_UTC",1,2), F.lit(":"), F.substring("HORA_UTC",3,2)), "HHmm") # formatando hora
                                           ),  # junta Data e Hora
                                "yyyy-MM-dd HHmm"
                                )
                    ) \
            .withColumn("Chuva", F.regexp_replace(F.col("PRECIPITACAO_TOTAL_MM"), ",", ".").cast(DoubleType()) ) \
            .withColumn("Temperatura", F.regexp_replace(F.col("TEMPERATURA_AR_C"), ",", ".").cast(DoubleType()) ) \
            .withColumn("Umidade_Perc", F.regexp_replace(F.col("UMIDADE_RELATIVA_PCT"), ",", ".").cast(DoubleType()) ) \
            .withColumn("Vento_m_s", F.regexp_replace(F.col("VENTO_VELOCIDADE_MS"), ",", ".").cast(DoubleType()) ) \
            .withColumn("UF", F.get_json_object(F.col("METADADOS"), "$.UF")) \
            .withColumn("estacao_met", F.get_json_object(F.col("METADADOS"), "$.ESTACAO")) \
            .select("DataHora", "Chuva", "Temperatura", "Umidade_Perc", "Vento_m_s", "uf", "estacao_met")

display(df_silver.limit(2))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>DataHora</th><th>Chuva</th><th>Temperatura</th><th>Umidade_Perc</th><th>Vento_m_s</th><th>uf</th><th>estacao_met</th></tr></thead><tbody><tr><td>2025-07-10T00:00:00.000Z</td><td>0.0</td><td>16.7</td><td>61.0</td><td>1.8</td><td>GO</td><td>CRISTALINA (FAZENDA SANTA MONICA)</td></tr><tr><td>2025-07-10T01:00:00.000Z</td><td>0.0</td><td>15.9</td><td>62.0</td><td>1.2</td><td>GO</td><td>CRISTALINA (FAZENDA SANTA MONICA)</td></tr></tbody></table></div>

# %% [markdown]
# ## 3. Persistência:
#
# Utilizar um dos Formatos Open Data (Delta Lake, Apache Iceberg ou Apache Hudi) para armazenar a tabela final.

# %%
# Dropar tabela case exista
spark.sql("DROP TABLE IF EXISTS aula.default.clima")
# Out:
# DataFrame[]

# %%
# Definindo o caminho de saída (simulação de um Data Lake)
caminho_parquet = "aula.default.clima"

df_silver = df_silver.withColumn("regiao", F.lit("")) # cria uma coluna vazia

df_silver.write.format("delta") \
    .mode("overwrite") \
    .option("compression", "snappy") \
    .partitionBy("UF") \
    .saveAsTable(caminho_parquet)

# %%
spark.table("aula.default.clima").limit(2).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>DataHora</th><th>Chuva</th><th>Temperatura</th><th>Umidade_Perc</th><th>Vento_m_s</th><th>uf</th><th>estacao_met</th><th>regiao</th></tr></thead><tbody><tr><td>2025-07-10T00:00:00.000Z</td><td>0.0</td><td>16.7</td><td>61.0</td><td>1.8</td><td>GO</td><td>CRISTALINA (FAZENDA SANTA MONICA)</td><td></td></tr><tr><td>2025-07-10T01:00:00.000Z</td><td>0.0</td><td>15.9</td><td>62.0</td><td>1.2</td><td>GO</td><td>CRISTALINA (FAZENDA SANTA MONICA)</td><td></td></tr></tbody></table></div>

# %% [markdown]
# ## 4. Recurso Avançado (Obrigatório)
#
# Demonstrar uma operação de UPSERT (Update ou Insert) ou DELETE na tabela final.

# %%
# %sql
-- update na coluna regiao
update aula.default.clima
SET regiao = 
    CASE 
        WHEN uf IN ('AC', 'AM', 'AP', 'PA', 'RO', 'RR', 'TO') THEN 'Norte'
        WHEN uf IN ('AL', 'BA', 'CE', 'MA', 'PB', 'PE', 'PI', 'RN', 'SE') THEN 'Nordeste'
        WHEN uf IN ('DF', 'GO', 'MT', 'MS') THEN 'Centro-Oeste'
        WHEN uf IN ('ES', 'MG', 'RJ', 'SP') THEN 'Sudeste'
        WHEN uf IN ('PR', 'RS', 'SC') THEN 'Sul'
        ELSE 'Região Não Mapeada' 
    END
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th></tr></thead><tbody><tr><td>255360</td></tr></tbody></table></div>

# %%
spark.table("aula.default.clima").limit(2).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>DataHora</th><th>Chuva</th><th>Temperatura</th><th>Umidade_Perc</th><th>Vento_m_s</th><th>uf</th><th>estacao_met</th><th>regiao</th></tr></thead><tbody><tr><td>2025-01-01T00:00:00.000Z</td><td>0.0</td><td>26.0</td><td>56.0</td><td>0.9</td><td>MS</td><td>CAMPO GRANDE</td><td>Centro-Oeste</td></tr><tr><td>2025-01-01T01:00:00.000Z</td><td>0.0</td><td>25.7</td><td>56.0</td><td>1.0</td><td>MS</td><td>CAMPO GRANDE</td><td>Centro-Oeste</td></tr></tbody></table></div>

# %%
spark.table("aula.default.clima").groupBy("UF").count().display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>UF</th><th>count</th></tr></thead><tbody><tr><td>MS</td><td>29184</td></tr><tr><td>DF</td><td>36480</td></tr><tr><td>GO</td><td>189696</td></tr></tbody></table></div>

# %%
spark.sql("""
    DELETE FROM aula.default.clima
    WHERE UF = 'DF'
""")
# Out:
# DataFrame[num_affected_rows: bigint]

# %%
spark.table("aula.default.clima").groupBy("UF").count().display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>UF</th><th>count</th></tr></thead><tbody><tr><td>MS</td><td>29184</td></tr><tr><td>GO</td><td>189696</td></tr></tbody></table></div>

# %% [markdown]
# ## RESTORE - trabalhando com versionamento

# %%
df = spark.sql("DESCRIBE HISTORY aula.default.clima")  # visualizar o histórico de alterações da tabela
display(df.select("version", "timestamp", "userId", "operation"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>version</th><th>timestamp</th><th>userId</th><th>operation</th></tr></thead><tbody><tr><td>2</td><td>2025-12-03T15:37:31.000Z</td><td>8602734324472921</td><td>DELETE</td></tr><tr><td>1</td><td>2025-12-03T15:37:27.000Z</td><td>8602734324472921</td><td>UPDATE</td></tr><tr><td>0</td><td>2025-12-03T15:37:23.000Z</td><td>8602734324472921</td><td>CREATE OR REPLACE TABLE AS SELECT</td></tr></tbody></table></div>

# %%
# %sql
RESTORE TABLE aula.default.clima TO VERSION AS OF 1; -- realiza o restore da versão 1
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>table_size_after_restore</th><th>num_of_files_after_restore</th><th>num_removed_files</th><th>num_restored_files</th><th>removed_files_size</th><th>restored_files_size</th></tr></thead><tbody><tr><td>1083575</td><td>3</td><td>0</td><td>1</td><td>0</td><td>174343</td></tr></tbody></table></div>

# %%
spark.table("aula.default.clima").groupBy("UF").count().display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>UF</th><th>count</th></tr></thead><tbody><tr><td>DF</td><td>36480</td></tr><tr><td>GO</td><td>189696</td></tr><tr><td>MS</td><td>29184</td></tr></tbody></table></div>

# %%
df = spark.sql("DESCRIBE HISTORY aula.default.clima")  # visualizar o histórico de alterações da tabela
display(df.select("version", "timestamp", "userId", "operation"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>version</th><th>timestamp</th><th>userId</th><th>operation</th></tr></thead><tbody><tr><td>3</td><td>2025-12-03T15:37:38.000Z</td><td>8602734324472921</td><td>RESTORE</td></tr><tr><td>2</td><td>2025-12-03T15:37:31.000Z</td><td>8602734324472921</td><td>DELETE</td></tr><tr><td>1</td><td>2025-12-03T15:37:27.000Z</td><td>8602734324472921</td><td>UPDATE</td></tr><tr><td>0</td><td>2025-12-03T15:37:23.000Z</td><td>8602734324472921</td><td>CREATE OR REPLACE TABLE AS SELECT</td></tr></tbody></table></div>
